# %% [markdown]
# # Probability Constraint Research

# %%
from pme.models import ProbabilityConstraint, ConstraintKind
from pme.signals.constraints import evaluate_constraints
prices={'title':.31,'conference':.29}
constraints=[ProbabilityConstraint(kind=ConstraintKind.SUBSET, variables=['title','conference'])]
evaluate_constraints(prices,constraints)
