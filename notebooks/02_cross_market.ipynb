# %% [markdown]
# # Cross-Venue Discrepancies
# Study executable best-ask vs best-bid gaps rather than midpoint differences.

# %%
import duckdb

db = duckdb.connect("../data/pme.duckdb", read_only=True)
db.execute("select * from opportunities order by net_edge desc limit 25").df()
