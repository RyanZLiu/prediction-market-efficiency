# %% [markdown]
# # Market Overview
# Inspect stored markets and recent quotes.

# %%
from pathlib import Path
import duckdb
db = duckdb.connect('../data/pme.duckdb', read_only=True)
db.execute('select venue, count(*) n from markets group by venue').df()
